# %%
import numpy as np
import scipy
from scipy import special
from matplotlib import cm
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
plt.style.use('seaborn-pastel')
import time

# %%
#1-ая разностная схема
L = 1
T = 0.5
a = 0.05
N_z = 100
N_t = 200
c = 0.5
h = 2*L / N_z
tau = T / N_t
r = c * tau / h #  число Куранта
z = np.arange(-L, L+h, h)
t = np.arange(0, T+tau, tau)
fi = np.zeros(N_z)
#задаем функцию фи
fi = np.exp(-np.power(z, 2)/(2*a**2))
E = np.zeros([len(t), len(z)])
E[:][0] = fi

#аналитическое решение
E_analit = np.zeros([len(t), len(z)])
for n in range(len(t)):
    E_analit[n] = 0.5*(np.exp(-np.power(z - c*t[n], 2)/(2*a**2)) + np.exp(-np.power(z + c*t[n], 2)/(2*a**2)))
for n in range(len(t)):
    E_analit[n][0] = 0
    E_analit[n][len(z)-1] = 0
    E[n][0] = 0
    E[n][len(z)-1] = 0
for j in range(1,len(z) - 1):
    E[1][j] = E[0][j] + (r**2 / 2) *(E[0][j+1] - 2 * E[0][j] + E[0][j-1])
for n in range(1, len(t)-1):
    for j in range(1, len(z)-1):
        E[n+1][j] = 2 * E[n][j] - E[n-1][j] + r**2*(E[n][j+1] - 2 * E[n][j] + E[n][j-1])
fig = plt.figure()
ax = plt.axes(xlim=(-L, L), ylim=(-1.5, 1.5))
line = []
N = 2
for j in range(N):
    temp, = plt.plot([], [])
    line.append(temp)
line = tuple(line)
def init():
    for j in range(N):
        line[j].set_data([], [])
    return line,
def animate(i):
    #x_i = np.arange(0, L, h)
    #y = g_t_h[i]
    x_i = z
    y1 = E[i]
    y2 = E_analit[i]
    line[0].set_data(x_i, y1)
    line[1].set_data(x_i, y2)
    return line,
print(E)
anim = FuncAnimation(fig, animate, init_func=init,
                               frames=20000, interval=0.1, blit=True, repeat = False)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [[0.00000000e+00 3.80816639e-84 8.92978691e-81 ... 8.92978691e-81
#   3.80816639e-84 0.00000000e+00]
#  [0.00000000e+00 2.12342808e-83 4.37454271e-80 ... 4.37454271e-80
#   2.12342808e-83 0.00000000e+00]
#  [0.00000000e+00 2.09375077e-82 3.79451817e-79 ... 3.79451817e-79
#   2.09375077e-82 0.00000000e+00]
#  ...
#  [0.00000000e+00 4.18817926e-30 8.91013550e-29 ... 8.91013550e-29
#   4.18817926e-30 0.00000000e+00]
#  [0.00000000e+00 5.51451558e-30 1.16425872e-28 ... 1.16425872e-28
#   5.51451558e-30 0.00000000e+00]
#  [0.00000000e+00 7.25255831e-30 1.51960340e-28 ... 1.51960340e-28
#   7.25255831e-30 0.00000000e+00]]

# %%
#2-ая разностная схема
L = 1
T = 3
a = 0.05
N_z = 100
N_t = 2000
c = 0.5
h = 2*L / N_z
tau = T / N_t
r = c * tau / h #  число Куранта
z = np.arange(-L, L+h, h)
t = np.arange(0, T+tau, tau)
fi = np.zeros(N_z)
#задаем функцию фи
fi = np.exp(-np.power(z, 2)/(2*a**2))
E = np.zeros([len(t), len(z)])
H = np.zeros([len(t), len(z)])
E[:][0] = fi
print(E[0][3])
#аналитическое решение
E_analit = np.zeros([len(t), len(z)])
for n in range(len(t)):
    E_analit[n] = 0.5*(np.exp(-np.power(z - c*t[n], 2)/(2*a**2)) + np.exp(-np.power(z + c*t[n], 2)/(2*a**2)))
for n in range(len(t)):
    E_analit[n][0] = 0
    E_analit[n][len(z)-1] = 0
    E[n][0] = 0
    E[n][len(z)-1] = 0
for j in range(len(z)-1):
    H[0][j+1] = r / 2 * (fi[j+1] - fi[j])
for n in range(len(t)-1):
    for j in range(1,len(z)-1):
        E[n+1][j] = E[n][j] + r*(H[n][j+1] - H[n][j])
    for j in range(len(z)-1):
        H[n+1][j+1] = H[n][j+1] + r * (E[n+1][j+1] - E[n+1][j])
fig = plt.figure()
ax = plt.axes(xlim=(-L, L), ylim=(-1.5, 1.5))
line = []
N = 2
for j in range(N):
    temp, = plt.plot([], [])
    line.append(temp)
line = tuple(line)
def init():
    for j in range(N):
        line[j].set_data([], [])
    return line,
def animate(i):
    x_i = z
    y1 = E[i]
    y2 = E_analit[i]
    line[0].set_data(x_i, y1)
    line[1].set_data(x_i, y2)
    return line,
print(E)
anim = FuncAnimation(fig, animate, init_func=init,
                               frames=20000, interval=1, blit=True, repeat = False)
# Out:
# 1.784346355085867e-77
# <img src="data:image/png;base64,..." width="640">
# [[0.00000000e+00 3.80816639e-84 8.92978691e-81 ... 8.92978691e-81
#   3.80816639e-84 0.00000000e+00]
#  [0.00000000e+00 1.00815686e-83 2.14634174e-80 ... 2.14634174e-80
#   1.00815686e-83 0.00000000e+00]
#  [0.00000000e+00 4.65095470e-83 8.90355361e-80 ... 8.90355361e-80
#   4.65095470e-83 0.00000000e+00]
#  ...
#  [0.00000000e+00 4.76854111e-05 1.52488199e-04 ... 1.52488199e-04
#   4.76854111e-05 0.00000000e+00]
#  [0.00000000e+00 3.62014348e-05 1.53536642e-04 ... 1.53536642e-04
#   3.62014348e-05 0.00000000e+00]
#  [0.00000000e+00 2.48315528e-05 1.54132262e-04 ... 1.54132262e-04
#   2.48315528e-05 0.00000000e+00]]

# %%
#3-я часть
L = 1
T = 100
a = 0.05
N_z = 100
N_t = 20000
c = 0.5
h = 2*L / N_z
tau = T / N_t
r = c * tau / h #  число Куранта
delta = L / 8
A0 = 10
z = np.arange(-L, L+h, h)
t = np.arange(0, T+tau, tau)
fi = np.zeros(N_z)
#задаем функцию фи
fi = np.exp(-np.power(z, 2)/(2*a**2))
E = np.zeros([len(t), len(z)])
H = np.zeros([len(t), len(z)])
E[:][0] = fi
print(E[0][3])

sigma = np.zeros(len(z))
for i in range(len(z)):
    if z[i] > - L and z[i] < - L + delta:
        sigma[i] = A0 * ((z[i] + L - delta)/ delta)**2
    elif z[i] > - L + delta and z[i] < L - delta:
        sigma[i] = 0
    else:
        sigma[i] = A0 * ((z[i] - L + delta)/ delta)**2            
#аналитическое решение
E_analit = np.zeros([len(t), len(z)])
for n in range(len(t)):
    E_analit[n] = 0.5*(np.exp(-np.power(z - c*t[n], 2)/(2*a**2)) + np.exp(-np.power(z + c*t[n], 2)/(2*a**2)))
for n in range(len(t)):
    E_analit[n][0] = 0
    E_analit[n][len(z)-1] = 0
    E[n][0] = 0
    E[n][len(z)-1] = 0
for j in range(len(z)-1):
    H[0][j+1] = r / 2 * (fi[j+1] - fi[j])
for n in range(len(t)-1):
    for j in range(1,len(z)-1):
        E[n+1][j] = (E[n][j] * (1 - 2*np.pi * sigma[j]*tau) + r*(H[n][j+1] - H[n][j])) / (1 + 2*np.pi * sigma[j]*tau)
    for j in range(len(z)-1):
        H[n+1][j+1] = (H[n][j+1]*(1 - 2*np.pi * (sigma[j]+sigma[j+1])*tau/2) + r * (E[n+1][j+1] - E[n+1][j])) / (1 + 2*np.pi * (sigma[j] + sigma[j+1])*tau/2)
fig = plt.figure()
ax = plt.axes(xlim=(-L, L), ylim=(-1.5, 1.5))
line = []
N = 2
for j in range(N):
    temp, = plt.plot([], [])
    line.append(temp)
line = tuple(line)
def init():
    for j in range(N):
        line[j].set_data([], [])
    return line,
def animate(i):
    x_i = z
    y1 = E[i]
    y2 = E_analit[i]
    line[0].set_data(x_i, y1)
    line[1].set_data(x_i, y2)
    return line,
print(E)
anim = FuncAnimation(fig, animate, init_func=init,
                               frames=20000, interval=0.5, blit=True, repeat = False)
# Out:
# 1.784346355085867e-77
# <img src="data:image/png;base64,..." width="640">
# [[ 0.00000000e+00  3.80816639e-84  8.92978691e-81 ...  8.92978691e-81
#    3.80816639e-84  0.00000000e+00]
#  [ 0.00000000e+00  5.94828631e-83  1.28262764e-79 ...  1.28262764e-79
#    5.94828631e-83  0.00000000e+00]
#  [ 0.00000000e+00  1.46278666e-81  3.04690560e-78 ...  3.04690560e-78
#    1.46217044e-81  0.00000000e+00]
#  ...
#  [ 0.00000000e+00  1.18542573e-16  7.69171996e-16 ...  7.69342420e-16
#    1.14214672e-16  0.00000000e+00]
#  [ 0.00000000e+00  1.12580845e-16  3.85310743e-16 ...  3.85360716e-16
#    1.07429984e-16  0.00000000e+00]
#  [ 0.00000000e+00  1.00235468e-16 -1.83837977e-17 ... -1.84566450e-17
#    9.45596896e-17  0.00000000e+00]]

# %%
def test_first(N_z, N_t):
    L = 1
    T = 3
    a = 0.05
    #N_z = 100
    #N_t = 20000
    c = 0.05
    h = 2*L / N_z
    tau = T / N_t
    r = c * tau / h #  число Куранта
    z = np.arange(-L, L+h, h)
    t = np.arange(0, T+tau, tau)
    fi = np.zeros(N_z)
    #задаем функцию фи
    fi = np.exp(-np.power(z, 2)/(2*a**2))
    E = np.zeros([len(t), len(z)])
    E[:][0] = fi
    for n in range(len(t)):
        E[n][0] = 0
        E[n][len(z)-1] = 0
    #аналитическое решение
    E_analit = np.zeros([len(t), len(z)])
    for n in range(len(t)):
        E_analit[n] = 0.5*(np.exp(-np.power(z - c*t[n], 2)/(2*a**2)) + np.exp(-np.power(z + c*t[n], 2)/(2*a**2)))
    for n in range(len(t)):
        E_analit[n][0] = 0
        E_analit[n][len(z)-1] = 0
    for j in range(1,len(z) - 2):
        E[1][j] = E[0][j] + (r**2 / 2) *(E[0][j+1] - 2 * E[0][j] + E[0][j-1])
    for n in range(1, len(t)-1):
        for j in range(1, len(z)-2):
            E[n+1][j] = 2 * E[n][j] - E[n-1][j] + r**2*(E[n][j+1] - 2 * E[n][j] + E[n][j-1])
    for n in range(len(t)):
        E[n][0] = 0
        E[n][len(z)-1] = 0
    return np.amax(abs(E - E_analit))

# %%
a = test_first(1000, 2000)
print(np.amax(a))
# Out:
# 0.00013775001725041536

# %%
#1-ая задача
norm_1 = test_first(800, 800)
norm_2 = test_first(1600, 1600)
norm = np.log(norm_1 / norm_2) / np.log(2)
print(norm)
# Out:
# 2.002008678433996

# %%
def test_second(N_z, N_t):
    L = 1
    T = 1
    a = 0.05
    #N_z = 100
    #N_t = 20000
    c = 0.05
    h = 2*L / N_z
    tau = T / N_t
    r = c * tau / h #  число Куранта
    z = np.arange(-L, L+h, h)
    t = np.arange(0, T+tau, tau)
    fi = np.zeros(N_z)
    #задаем функцию фи
    fi = np.exp(-np.power(z, 2)/(2*a**2))
    E = np.zeros([len(t), len(z)])
    H = np.zeros([len(t), len(z)])
    E[:][0] = fi
    #аналитическое решение
    E_analit = np.zeros([len(t), len(z)])
    for n in range(len(t)):
        E_analit[n] = 0.5*(np.exp(-np.power(z - c*t[n], 2)/(2*a**2)) + np.exp(-np.power(z + c*t[n], 2)/(2*a**2)))
    for n in range(len(t)):
        E_analit[n][0] = 0
        E_analit[n][len(z)-1] = 0
        E[n][0] = 0
        E[n][len(z)-1] = 0
    for j in range(len(z)-1):
        H[0][j+1] = r / 2 * (fi[j+1] - fi[j])
    for n in range(len(t)-1):
        for j in range(1,len(z)-2):
            E[n+1][j] = E[n][j] + r*(H[n][j+1] - H[n][j])
        for j in range(len(z)-2):
            H[n+1][j+1] = H[n][j+1] + r * (E[n+1][j+1] - E[n+1][j])
    return np.amax(abs(E - E_analit))

# %%
#2-ая задача
norm_1 = test_second(800, 800)
norm_2 = test_second(1600, 1600)
norm = np.log(norm_1 / norm_2) / np.log(2)
print(norm)
# Out:
# 2.000349303058571

# %%
#3-я часть, с другой сигмой
L = 1
T = 100
a = 0.05
N_z = 100
N_t = 20000
c = 0.5
h = 2*L / N_z
tau = T / N_t
r = c * tau / h #  число Куранта
delta = L / 8
A0 = 0.7
z = np.arange(-L, L+h, h)
t = np.arange(0, T+tau, tau)
fi = np.zeros(N_z)
#задаем функцию фи
fi = np.exp(-np.power(z, 2)/(2*a**2))
E = np.zeros([len(t), len(z)])
H = np.zeros([len(t), len(z)])
E[:][0] = fi
print(E[0][3])

sigma = np.zeros(len(z))
for i in range(len(z)):
    if z[i] > - L and z[i] < - L + delta:
        sigma[i] = A0 * np.exp(((z[i] + L - delta)/ delta)**2)
    elif z[i] > - L + delta and z[i] < L - delta:
        sigma[i] = 0
    else:
        sigma[i] = A0 * np.exp(((z[i] - L + delta)/ delta)**2)  
#for i in range(len(z)):
    #if z[i] > - L and z[i] < - L + delta:
        #sigma[i] = 1.0 * np.cos(((z[i] + L - delta)/ delta))**2
    #elif z[i] > - L + delta and z[i] < L - delta:
        #sigma[i] = 0
    #else:
        #sigma[i] = 1.0* np.cos((z[i] - L + delta)/ delta)**2
#for i in range(len(z)):
    #if z[i] > - L and z[i] < - L + delta:
        #sigma[i] = 7 * ((z[i] + L - delta)/ delta)**4
    #elif z[i] > - L + delta and z[i] < L - delta:
        #sigma[i] = 0
    #else:
        #sigma[i] = 7 *((z[i] - L + delta)/ delta)**4
#аналитическое решение
E_analit = np.zeros([len(t), len(z)])
for n in range(len(t)):
    E_analit[n] = 0.5*(np.exp(-np.power(z - c*t[n], 2)/(2*a**2)) + np.exp(-np.power(z + c*t[n], 2)/(2*a**2)))
for n in range(len(t)):
    E_analit[n][0] = 0
    E_analit[n][len(z)-1] = 0
    E[n][0] = 0
    E[n][len(z)-1] = 0
for j in range(len(z)-1):
    H[0][j+1] = r / 2 * (fi[j+1] - fi[j])
for n in range(len(t)-1):
    for j in range(1,len(z)-1):
        E[n+1][j] = (E[n][j] * (1 - 2*np.pi * sigma[j]*tau) + r*(H[n][j+1] - H[n][j])) / (1 + 2*np.pi * sigma[j]*tau)
    for j in range(len(z)-1):
        H[n+1][j+1] = (H[n][j+1]*(1 - 2*np.pi * (sigma[j]+sigma[j+1])*tau/2) + r * (E[n+1][j+1] - E[n+1][j])) / (1 + 2*np.pi * (sigma[j] + sigma[j+1])*tau/2)
fig = plt.figure()
ax = plt.axes(xlim=(-L, L), ylim=(-1.5, 1.5))
line = []
N = 2
for j in range(N):
    temp, = plt.plot([], [])
    line.append(temp)
line = tuple(line)
def init():
    for j in range(N):
        line[j].set_data([], [])
    return line,
def animate(i):
    x_i = z
    y1 = E[i]
    y2 = E_analit[i]
    line[0].set_data(x_i, y1)
    line[1].set_data(x_i, y2)
    return line,
print(E)
anim = FuncAnimation(fig, animate, init_func=init,
                               frames=20000, interval=0.5, blit=True, repeat = False)
# Out:
# 1.784346355085867e-77
# <img src="data:image/png;base64,..." width="640">
# [[0.00000000e+00 3.80816639e-84 8.92978691e-81 ... 8.92978691e-81
#   3.80816639e-84 0.00000000e+00]
#  [0.00000000e+00 7.02160815e-83 1.42890875e-79 ... 1.42890875e-79
#   7.02160815e-83 0.00000000e+00]
#  [0.00000000e+00 2.18071716e-81 3.87357008e-78 ... 3.87357008e-78
#   2.17966476e-81 0.00000000e+00]
#  ...
#  [0.00000000e+00 4.19522215e-19 2.22928922e-18 ... 2.03334390e-18
#   1.08884959e-18 0.00000000e+00]
#  [0.00000000e+00 7.16633181e-19 1.47953997e-18 ... 1.29608945e-18
#   1.33662831e-18 0.00000000e+00]
#  [0.00000000e+00 9.73947850e-19 6.81147442e-19 ... 5.19807422e-19
#   1.51669980e-18 0.00000000e+00]]
